# %% [markdown]
# # Visualizing Chipotle's Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import collections
import matplotlib.pyplot as plt 

# set this so the graphs open internally
# %matplotlib inline

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo= pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep='\t')

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price  order_price
# 0                                                NaN     $2.39          2.39
# 1                                       [Clementine]     $3.39          3.39
# ...

# %% [markdown]
# ### Step 5. Create a histogram of the top 5 items bought

# %%
top_five = chipo.groupby(['item_name']).sum().sort_values(['quantity'],ascending=False).drop(['order_id'],axis=1).head()
top_five.plot(kind='bar')
plt.xlabel('Items')
plt.ylabel('Quantity')
plt.title('Top 5 Items Sold')
plt.legend('')

# %% [markdown]
# ### Step 6. Create a scatterplot with the number of items orderered per order price
# #### Hint: Price should be in the X-axis and Items ordered in the Y-axis

# %%
noitperitpri = chipo

# %%
noitperitpri['order_price'] = (noitperitpri['quantity']*noitperitpri['item_price'].apply(lambda x: float(x[1:])))

# %%
noitperitpri = noitperitpri.groupby(['order_id']).sum()

# %%
chipo_scatter, axes = plt.subplots()
axes.scatter(noitperitpri['order_price'],noitperitpri['quantity'])
#There is one anomalous order of value $1,000
axes.set_xlim(0,350)
axes.set_xlabel('Order Value, $')
axes.set_ylabel('No Items Ordered, $')
axes.set_title('No Items Ordered vs Order Value')
# Out:
# Text(0.5,1,'No Items Ordered vs Order Value')

# %% [markdown]
# ### Step 7. BONUS: Create a question and a graph to answer your own question.

# %%
# Out:
# 0        $2.39
# 1        $3.39
# 2        $3.39
# 3        $2.39
# 4       $16.98
# 5       $10.98
# 6        $1.69
# 7       $11.75
# 8        $9.25
# 9        $9.25
# 10       $4.45
# 11       $8.75
# 12       $8.75
# 13      $11.25
# 14       $4.45
# 15       $2.39
# 16       $8.49
# 17       $8.49
# 18       $2.18
# 19       $8.75
# 20       $4.45
# 21       $8.99
# 22       $3.39
# 23      $10.98
# 24       $3.39
# 25       $2.39
# 26       $8.49
# 27       $8.99
# 28       $1.09
# 29       $8.49
#          ...
# 4592    $11.75
# 4593    $11.75
# 4594    $11.75
# 4595     $8.75
# 4596     $4.45
# 4597     $1.25
# 4598     $1.50
# 4599     $8.75
# 4600     $4.45
# 4601     $1.25
# 4602     $9.25
# 4603     $9.25
# 4604     $8.75
# 4605     $4.45
# 4606     $1.25
# 4607    $11.75
# 4608    $11.25
# 4609     $1.25
# 4610    $11.75
# 4611    $11.25
# 4612     $9.25
# 4613     $2.15
# 4614     $1.50
# 4615     $8.75
# 4616     $4.45
# 4617    $11.75
# 4618    $11.75
# ...

# %%
items_ordered = chipo.groupby(['item_name']).sum()

# %%
items_ordered['average price, $'] = items_ordered['order_price']/items_ordered['quantity']

# %%
items_ordered
# Out:
#                                        order_id  quantity  order_price  \
# item_name
# 6 Pack Soft Drink                         52322        55       369.93
# Barbacoa Bowl                             53972        66       672.36
# Barbacoa Burrito                          74718        91       894.75
# Barbacoa Crispy Tacos                      5613        12       138.71
# Barbacoa Salad Bowl                        9708        10       106.40
# Barbacoa Soft Tacos                       18725        25       250.46
# Bottled Water                            175944       211       649.18
# Bowl                                        472         4        74.00
# Burrito                                    1550         6        44.40
# Canned Soda                               76396       126       191.84
# Canned Soft Drink                        304753       351       603.75
# Carnitas Bowl                             62742        71       830.71
# ...
